# %% [markdown]
# # Timeseries
# ## Seasonal Examples

# %%
import os
import sys
module_path = os.path.abspath(os.path.join(r'..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import numpy as np
import pandas as pd
import timeseries as ts

# %% [markdown]
# Open the dataset, build a list from the desired feature

# %%
cve_df = pd.read_csv(r'..\data\cve_tweets_by_day.csv')
series = cve_df['count'].tolist()

# %% [markdown]
# Predict cycle period, this data has a weekly (7) and monthly (30) cycle

# %%
ts.cycle_periods(series)
# Out:
# [7, 30]

# %% [markdown]
# Decompose the series into it component parts:
#
# - source
# - trend (moving average)
# - seasonal
# - residual
#
# plot() plots each, with a mean line, residual also plots a zero line.

# %%
decomposed = ts.decompose(series)
decomposed.plot()
