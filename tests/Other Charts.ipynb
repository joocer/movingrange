# %% [markdown]
# # Other Plots

# %%
import os
import sys
module_path = os.path.abspath(os.path.join(r'..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import pandas as pd
import timeseries as ts

# %%
df = pd.read_csv('../data/min-temp.csv')
series = df['Temp'].tolist()

# %% [markdown]
# ## Waterfall Plot

# %%
ts.plot_waterfall_chart(series[:20])

# %% [markdown]
# ## Bollinger Bands

# %%
ts.plot_bollinger_bands(df['Temp'].head(365))
